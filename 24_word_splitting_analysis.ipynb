# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('output/KoplenigEtAl/WordSplitting/entropies.csv')

# %%
df.head()

# %%
for book_name in df['book'].unique():
    book_df = df[df['book'] == book_name].groupby('n_types').mean().reset_index()
    assert len(book_df) == book_df['n_types'].nunique()
    x = book_df['D_order'].tolist()
    y = book_df['D_structure'].tolist()
    labels = book_df['n_types'].tolist()
    fig, ax = plt.subplots()
    ax.scatter(x, y)
    plt.xlabel('Word order information')
    plt.ylabel('Word structure information')
    plt.title(f'{book_name}')
    for i, txt in enumerate(labels):
        ax.annotate(txt, (x[i], y[i]), rotation=45)
