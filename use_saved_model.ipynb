# %%
from train import LSTMLanguageModel, load_losses, plot_losses, print_pred

# %%
model = LSTMLanguageModel.load('output/simple_lm.pth')

# %%
losses = load_losses('output/loss_vs_epoch.txt')

# %%
plot_losses(list(losses.values()))

# %%
print_pred(model, test_data, word_to_ix, ix_to_word)
